# %% [markdown]
# # Python

# %%
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Bilder
#
# #### in einer Markdown-Zelle:
# `<img src="images/StatGeschichte_Felsmalerei.jpg" width="50%">`
# <img src="images/StatGeschichte_Felsmalerei.jpg" width="50%">
#
# #### in einer Code-Zelle

# %%
from IPython.display import Image
Image(filename='images/StatGeschichte_Felsmalerei.jpg', width='50%')

# %% [markdown]
# #### in Jupyter direkt per drag&drop
#
# ![alt text](images/StatGeschichte_Felsmalerei.jpg "Title of image if hovering")
#
# ( Größe läßt sich leider nicht anpassen, das: ![alt text](images/Logo_stan_homepage.png =250x100) funktioniert nicht)

# %% [markdown]
# ### PyStan Ergebnis-Bilder doppelt
#     You can output a single plot by capturing the output Figure. Change your code from
#       fit.plot()
#     to instead be
#       fig = fit.plot()

# %% [markdown]
# ### Eine Tabelle mit Ausrichtung des Texts
# geht auch mit Mathe-Formeln
#
# | Name | Description                        | age
# | :-   |-------------:                      | :-:
# |Mary  | She is a nice girl.                | 20
# | Jackie Junior | He is a very naughty boy. | 5

# %% [markdown]
# ### größere Beschriftung für Folien
#
#     from matplotlib import rcParams
#     rcParams.update({'font.size': 14}
#
#
# ### nur bestimmt x-ticks
#
#      plt.xticks([0, 1, 2, 3, 4])
#      plt.xticks([])                # keine
#
# ### x-ticks benamsen
#
#     plt.xticks([liste der Orte/Koordinaten], [String-Liste der Namen])
#
# ### lazy Zwischenräume bei subplots und Beschriftungen
#
#     plt.tight_layout()
#
# ### histogramm
#
#     edgecolor='black'           # vermeidet Flächen-Farb-Brei

# %% [markdown]
# # Color
#
# Farbiger Text geht auch mit Mathe-Formeln: <font color='green'>$a^2+b^2$</font>
#
# Innerhalb $\LaTeX$ ebenfalls:
#
# Anmarkern im Hintergrund:
#
# <div class="alert alert-block alert-info">
# $${E}(X) =\int_{-\infty}^{\infty} X \cdot f(X) \mathrm{d}X$$</div>
#
# <div class="alert alert-block alert-info">Tip: Use blue boxes for Tips and notes. If it’s a note, you don’t have to include the word “Note”.</div>
#
# <div class="alert alert-block alert-warning">Example: Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed.</div>
#
# <div class="alert alert-block alert-success">Up to you: Use green boxes sparingly, and only for some specific purpose that the other boxes can't cover. For example, if you have a lot of related content to link to, maybe you decide to use green boxes for related links from each section of a notebook. </div>
#
# <div class="alert alert-block alert-danger">Just don't: In general, just avoid the red boxes.</div>

# %% [markdown]
# # LaTeX
# * innerhalb "Dollar": Formel $a^2$ im Fließtext
# * abgesetzte Formel "Doppeldollar": $$a^2+b^2=c^2$$
# * oder in code-Zelle:

# %%
# %%latex
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# # $\LaTeX$
#
# $$U=\frac{\mathrm{d}l}{\mathrm{d}\theta}\stackrel{\mathbf{!}}= 0$$
#
# $$\underset{a, b}{\mathrm{argmin}}\sum_i(y_i-f_{a,b}(x_i))^2$$

# %% [markdown]
# # Ausführen, Timing, Debuggen

# %%
def slow_function(x):
    for i in range(x):
        for j in range(x):
            for k in range(x):
                if (x<i) and (x<j) and (x<k):
                    print('something wrong')

# %prun slow_function(100)

# %% [markdown]
#     4 function calls in 0.043 seconds
#
#     Ordered by: internal time
#
#     ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.043    0.043    0.043    0.043 <ipython-input-1-c99d1918e5c5>:1(slow_function)
#         1    0.000    0.000    0.043    0.043 {built-in method builtins.exec}
#         1    0.000    0.000    0.043    0.043 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# # R kernel
# https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
