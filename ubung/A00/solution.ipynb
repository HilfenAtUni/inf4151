# %% [markdown]
# Name,Vorname: xx
#
# Matrikelnummer: xx
#
# Studienfach und -gang: Informatik MSc.
#
# ![image.png](attachment:image.png)

# %%
import statsmodels.api as sm
sm.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# Python: 3.5.2.final.0
# OS: Linux 4.4.0-119-generic #143-Ubuntu SMP Mon Apr 2 16:08:24 UTC 2018 x86_64
# byteorder: little
# LC_ALL: None
# LANG: de_DE.UTF-8
#
# Statsmodels
# ...
#
# Installed: 0.8.0 (/media/self/develop/branch.git/works/uni/private/fachrichtung/ma/uni_tue_exercise/python3/lib/python3.5/site-packages/statsmodels)
#
# Required Dependencies
# ...
#
# cython: 0.28.2 (/media/self/develop/branch.git/works/uni/private/fachrichtung/ma/uni_tue_exercise/python3/lib/python3.5/site-packages/Cython)
# numpy: 1.14.2 (/media/self/develop/branch.git/works/uni/private/fachrichtung/ma/uni_tue_exercise/python3/lib/python3.5/site-packages/numpy)
# scipy: 1.0.1 (/media/self/develop/branch.git/works/uni/private/fachrichtung/ma/uni_tue_exercise/python3/lib/python3.5/site-packages/scipy)
# pandas: 0.22.0 (/media/self/develop/branch.git/works/uni/private/fachrichtung/ma/uni_tue_exercise/python3/lib/python3.5/site-packages/pandas)
# ...

# %% [markdown]
# ![A00-01.png](attachment:A00-01.png)
